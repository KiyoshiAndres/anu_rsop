# %%
import numpy as np
import pyvista as pv

# %% [markdown]
# ## Rotation Function

# %%
def rotate_points(points, theta, phi, alpha):
    # Create rotation matrix for rotation around z-axis
    Rz = np.array([
        [np.cos(theta), -np.sin(theta), 0],
        [np.sin(theta), np.cos(theta), 0],
        [0, 0, 1]
    ])
    
    # Create rotation matrix for rotation around y-axis
    Ry = np.array([
        [np.cos(phi), 0, np.sin(phi)],
        [0, 1, 0],
        [-np.sin(phi), 0, np.cos(phi)]
    ])
    
    # Create rotation matrix for rotation around x-axis
    Rx = np.array([
        [1, 0, 0],
        [0, np.cos(alpha), -np.sin(alpha)],
        [0, np.sin(alpha), np.cos(alpha)]
    ])
    
    # Combine the rotations (Here @ is matrix multiplication)
    R = Rz @ Ry @ Rx

    # Apply the rotation matrix to each point (R.T is the transpose of R)
    rotated_points = points @ R.T
    
    return rotated_points

# %% [markdown]
# https://en.wikipedia.org/wiki/Active_and_passive_transformation#Passive_transformation
# For details on why we use Transpose=Inverse.

# %% [markdown]
# ## Circle on XY Plane

# %%
def generate_circle_points(n, radius=1.0):
    # Evenly spaced values over the interval 0,2pi. 
    angles = np.linspace(0, 2 * np.pi, n, endpoint=False)
    # Makes the 3D array
    points = np.column_stack((radius * np.cos(angles), radius * np.sin(angles), np.zeros(n)))
    return points

# %% [markdown]
# We should aim for n=4x to have the axes and antipodals. To that end, the user will input a number x, instead of n.

# %%
x = 10
n = 4 * x
# Generate circle points
circle_points = generate_circle_points(n)

# %% [markdown]
# ## Rotate Circle

# %% [markdown]
# Low number of points in original circle and high number of rotations will give concentric circles.

# %%
# Number of rotations
n_rotations = 5
angles = np.linspace(0, np.pi, n_rotations, endpoint=False)  # Uniformly spaced angles

sphere_points = []

for phi in angles:
    rotated_circle = rotate_points(circle_points, 0, phi, 0)  # Rotate around y-axis
    sphere_points.append(rotated_circle)

sphere_points = np.vstack(sphere_points)

# %% [markdown]
# ## Small Optimization

# %%
threshold = 0.0000001

# Set entries to zero where absolute value is less than the threshold
sphere_points[np.abs(sphere_points) < threshold] = 0

# Remove duplicate points
sphere_points = np.unique(sphere_points, axis=0)

# %%
print(sphere_points)
# Out:
# [[-1.          0.          0.        ]
#  [-0.98768834 -0.15643447  0.        ]
#  [-0.98768834  0.15643447  0.        ]
#  [-0.95105652 -0.30901699  0.        ]
#  [-0.95105652  0.30901699  0.        ]
#  [-0.89100652 -0.4539905   0.        ]
#  [-0.89100652  0.4539905   0.        ]
#  [-0.80901699 -0.58778525  0.        ]
#  [-0.80901699  0.          0.58778525]
#  [-0.80901699  0.         -0.58778525]
#  [-0.80901699  0.58778525  0.        ]
#  [-0.79905665 -0.15643447  0.58054864]
#  [-0.79905665  0.15643447 -0.58054864]
#  [-0.79905665  0.15643447  0.58054864]
#  [-0.79905665 -0.15643447 -0.58054864]
#  [-0.76942088 -0.30901699  0.55901699]
#  [-0.76942088  0.30901699  0.55901699]
#  [-0.15643447  0.98768834  0.        ]
#  [-0.14029078 -0.89100652  0.43177062]
#  [-0.14029078  0.89100652  0.43177062]
#  [-0.14029078  0.89100652 -0.43177062]
#  [-0.14029078 -0.89100652 -0.43177062]
#  [-0.12655814 -0.98768834  0.09194987]
#  [-0.12655814  0.98768834 -0.09194987]
#  [-0.12655814  0.98768834  0.09194987]
#  [-0.12655814 -0.98768834 -0.09194987]
#  [-0.0954915  -0.95105652  0.29389263]
#  [-0.0954915   0.95105652 -0.29389263]
#  [-0.0954915   0.95105652  0.29389263]
#  [-0.0954915  -0.95105652 -0.29389263]
#  [-0.04834091 -0.98768834  0.14877802]
#  [-0.04834091  0.98768834 -0.14877802]
#  [-0.04834091  0.98768834  0.14877802]
#  [-0.04834091 -0.98768834 -0.14877802]
#  [ 0.         -1.          0.        ]
#  [ 0.          1.          0.        ]
#  [ 0.04834091 -0.98768834 -0.14877802]
#  [ 0.04834091  0.98768834  0.14877802]
#  [ 0.04834091  0.98768834 -0.14877802]
#  [ 0.04834091 -0.98768834  0.14877802]
#  [ 0.0954915  -0.95105652 -0.29389263]
#  [ 0.0954915   0.95105652  0.29389263]
#  [ 0.0954915  -0.95105652  0.29389263]
#  [ 0.0954915   0.95105652 -0.29389263]
#  [ 0.12655814 -0.98768834 -0.09194987]
#  [ 0.12655814  0.98768834  0.09194987]
#  [ 0.12655814  0.98768834 -0.09194987]
#  [ 0.12655814 -0.98768834  0.09194987]
#  [ 0.14029078  0.89100652  0.43177062]
#  [ 0.14029078 -0.89100652 -0.43177062]
#  [ 0.14029078 -0.89100652  0.43177062]
#  [ 0.14029078  0.89100652 -0.43177062]
#  [ 0.15643447 -0.98768834  0.        ]
#  [ 0.15643447  0.98768834  0.        ]
#  [ 0.18163563  0.80901699  0.55901699]
#  [ 0.18163563 -0.80901699 -0.55901699]
#  [ 0.18163563 -0.80901699  0.55901699]
#  [ 0.18163563  0.80901699 -0.55901699]
#  [ 0.21850801  0.70710678  0.67249851]
#  [ 0.21850801 -0.70710678 -0.67249851]
#  [ 0.21850801 -0.70710678  0.67249851]
#  [ 0.21850801  0.70710678 -0.67249851]
#  [ 0.25       -0.95105652 -0.18163563]
#  [ 0.25        0.58778525  0.76942088]
#  [ 0.25        0.95105652  0.18163563]
#  [ 0.25       -0.58778525  0.76942088]
#  [ 0.25       -0.58778525 -0.76942088]
#  [ 0.25        0.58778525 -0.76942088]
#  [ 0.25        0.95105652 -0.18163563]
#  [ 0.25       -0.95105652  0.18163563]
#  [ 0.27533616 -0.4539905   0.84739756]
#  [ 0.27533616  0.4539905   0.84739756]
#  [ 0.27533616 -0.4539905  -0.84739756]
#  [ 0.27533616  0.4539905  -0.84739756]
#  [ 0.29389263  0.30901699  0.9045085 ]
#  [ 0.29389263 -0.30901699  0.9045085 ]
#  [ 0.29389263 -0.30901699 -0.9045085 ]
#  [ 0.29389263  0.30901699 -0.9045085 ]
#  [ 0.30521248 -0.15643447  0.93934743]
#  [ 0.30521248  0.15643447  0.93934743]
#  [ 0.30521248 -0.15643447 -0.93934743]
#  [ 0.30521248  0.15643447 -0.93934743]
#  [ 0.30901699 -0.95105652  0.        ]
#  [ 0.30901699  0.          0.95105652]
#  [ 0.30901699  0.         -0.95105652]
#  [ 0.30901699  0.95105652  0.        ]
#  [ 0.36728603 -0.89100652 -0.26684892]
#  [ 0.36728603  0.89100652  0.26684892]
#  [ 0.36728603 -0.89100652  0.26684892]
#  [ 0.36728603  0.89100652 -0.26684892]
#  [ 0.4539905  -0.89100652  0.        ]
#  [ 0.4539905   0.89100652  0.        ]
#  [ 0.47552826 -0.80901699 -0.3454915 ]
#  [ 0.47552826  0.80901699  0.3454915 ]
#  [ 0.47552826 -0.80901699  0.3454915 ]
#  [ 0.47552826  0.80901699 -0.3454915 ]
#  [ 0.5720614  -0.70710678 -0.41562694]
#  [ 0.5720614   0.70710678  0.41562694]
#  [ 0.5720614  -0.70710678  0.41562694]
#  [ 0.5720614   0.70710678 -0.41562694]
#  [ 0.58778525 -0.80901699  0.        ]
#  [ 0.58778525  0.80901699  0.        ]
#  [ 0.6545085  -0.58778525 -0.47552826]
#  [ 0.6545085  -0.58778525  0.47552826]
#  [ 0.6545085   0.58778525  0.47552826]
#  [ 0.6545085   0.58778525 -0.47552826]
#  [ 0.70710678 -0.70710678  0.        ]
#  [ 0.70710678  0.70710678  0.        ]
#  [ 0.72083942  0.4539905   0.52372049]
#  [ 0.72083942 -0.4539905  -0.52372049]
#  [ 0.72083942 -0.4539905   0.52372049]
#  [ 0.72083942  0.4539905  -0.52372049]
#  [ 0.76942088 -0.30901699  0.55901699]
#  [ 0.76942088  0.30901699  0.55901699]
#  [ 0.76942088 -0.30901699 -0.55901699]
#  [ 0.76942088  0.30901699 -0.55901699]
#  [ 0.79905665  0.15643447  0.58054864]
#  [ 0.79905665 -0.15643447 -0.58054864]
#  [ 0.79905665 -0.15643447  0.58054864]
#  [ 0.79905665  0.15643447 -0.58054864]
#  [ 0.80901699 -0.58778525  0.        ]
#  [ 0.80901699  0.          0.58778525]
#  [ 0.80901699  0.         -0.58778525]
#  [ 0.80901699  0.58778525  0.        ]
#  [ 0.89100652 -0.4539905   0.        ]
#  [ 0.89100652  0.4539905   0.        ]
#  [ 0.95105652 -0.30901699  0.        ]
#  [ 0.95105652  0.30901699  0.        ]
#  [ 0.98768834 -0.15643447  0.        ]
#  [ 0.98768834  0.15643447  0.        ]
#  [ 1.          0.          0.        ]]

# %% [markdown]
# ## Visualization

# %%
# Visualize using PyVista
plotter = pv.Plotter()
plotter.add_points(sphere_points, color='blue', point_size=5)
plotter.show_grid()
plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:64514/index.html?ui=P_0x15aaa0d30_0&reconnect=auto" class="pyvista…
